# %%
with open('sample.txt','w') as f:
  f.write('hello world')

# %%
try:
  with open('sample1.txt','r') as f:
    print(f.read())
except:
  print('ファイルが開けません')
# Out:
# ファイルが開けません

# %%
try:
  with open('sample.txt','r') as f:
    print(f.read())
    L = [1,2,3]

except FileNotFoundError:
  print('File not found')
except NameError:
  print('Variable not defined')

except ZeroDivisionError:
  print('ZeroDivision')
except Exception as e:
  print(e)

else:
  print('else')
finally:
  print('finally')
# Out:
# hello world
# else
# finally

# %%
raise ZeroDivisionError('aise hi try kr raha hu')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_29131/4209740347.py in <cell line: 0>()
# ----> 1 raise ZeroDivisionError('aise hi try kr raha hu')
#
# ZeroDivisionError: aise hi try kr raha hu

# %%
class Bank:
  def __init__(self,balance):
    self.balance = balance

  def withdraw(self,amount):
    if amount < 0:
      raise Exception('Amount cant be negative')
    if self.balance < amount:
      raise Exception('Insufficient balance')
    self.balance -= amount
    return self.balance

obj = Bank(10000)
try:
  obj.withdraw(15000)
except Exception  as e:
  print(e)
else:
  print(obj.balance)

# %%
class MyException(Exception):
  def __init__(self,message):
    print(message)

class Bank:
  def __init__(self,balance):
    self.balance = balance

  def withdraw(self,amount):
    if amount < 0:
      raise Exception('Amount cant be negative')
    if self.balance < amount:
      raise Exception('Insufficient balance')
    self.balance -= amount
    return self.balance

obj = Bank(10000)
try:
  obj.withdraw(15000)
except Exception  as e:
  print(e)
else:
  print(obj.balance)

# %%
from os import device_encoding
class Google:

  def __init__(self,name,email,password,device):
    self.name = name
    self.email = email
    self.password = password
    self.device = device

  def login(self,email,password,device):
    if device!=self.device:
      raise SecurityError('wrong device')
    if email == self.email and password == self.password:
      print('login successful')
    else:
      raise Exception('login failed')
class SecurityError(Exception):
  def logout(self):
    print('logout successful')
  def __init__(self,message):
    print(message)

obj = Google('Avinash','avinashoraon498@gmail.com','1234','android')

try:
  obj.login('avinashoraon498@gmail.com','1234','android')
except SecurityError as e:
  e.logout()
else:
  print(obj.name)
finally:
  print('database connection closed')

# %% [markdown]
# LEGB Rule

# %%
a = 2 #global
def temp():
  b = 3 #local
  print(b)
temp()
print(a)

# %%
a = 2 #global
def temp():
  global a
  a+=1
  print(a)
temp()
print(a)

# %%
def temp():
  global a
  a=1
  print(a)
temp()
print(a)

# %%
def temp(z): #z is local variable
  print(z)
a =5
temp(a)
print(a)

# %%
#built in scope
print('hello')
type('hello')
import builtins
dir(builtins)

# %%
#renaming builtins
L = [1,2,3]
max(L)

def max():
  print('hello')
max(L)

# %%
#Enclosing scope
def outer():
  def inner():
    print('inner')
  inner()
  print('outer')

outer()
print('main')

# %%
#In python functions are 1st class citizens

def modify(func,num):
  return func(num)

def square(num):
  return num**2

modify(square,4)

# %%
def my_decorator(func):
  def wrapper():
    print('*************')
    func()
    print('*************')
  return wrapper

def hello():
  print('hello world')

def bye():
  print('bye world')

a = my_decorator(hello)
a()
b = my_decorator(bye)
b()

# %%
def my_decorator(func):
  def wrapper():
    print('*************')
    func()
    print('*************')
  return wrapper
@my_decorator
def hello():
  print('hello world')

hello()

# %%
import time

def timer(func):
  def wrapper(*args):
    start = time.time()
    func(*args)
    print('Time taken',func.__name__,time.time()-start,'secs')
  return wrapper

@timer
def hello():
  print('hello')
  time.sleep(2)

@timer
def display():
  print('Display something')
  time.sleep(4)

@timer
def square(num):
  time.sleep(4)
  return num**2

square(2)

# %%
def sanity_check(data_type):
  def outer_wrapper(func):
    def inner_wrapper(*args):
      if type(*args) == data_type:
        func(*args)
      else:
        raise TypeError('Ye datatype nahi chalega')
    return inner_wrapper
  return outer_wrapper

@sanity_check(int)
def square(num):
  print(num**2)

@sanity_check(str)
def greet(name):
  print('hello')

greet('hello')

# %% [markdown]
# Recursion

# %%
def mul(a,b):
  if b ==1:
    return a
  else :
    return a + mul(a,b-1)

mul(2,3)

# %%
def fact(b):
  if b ==1:
    return b
  else :
    return b*fact(b-1)

fact(5)

# %%
def palindrome(s):
  if len(s) <= 1:
    print('palindrome')
  else:
    if s[0] == s[-1]:
      palindrome(s[1:-1])
    else:
      print('not palindrome')

palindrome('abkdlaba')

# %%
import time
def fib(m):
  if m == 0 or m ==1:
    return 1
  else:
    return fib(m-1) + fib(m-2)

start = time.time()
fib(3)
print(time.time()-start)

# %%
#dynamic programming
import time
def memo(m,d):
  if m in d:
    return d[m]
  else:
    d[m] = memo(m-1,d) + memo(m-2,d)
    return d[m]
start = time.time()
d = {0:1,1:1}
memo(48,d)
print(time.time()-start)

# %% [markdown]
# Iterators

# %%
#An iterator is an object that allows the programmer to traverse through a sequence of data without
#having to store the entire data in the memory

L = [ x for x in range(1,1000000)]

import sys
print(sys.getsizeof(L)/1024)

x = range(1,10000000)
print(sys.getsizeof(x)/1024)
# Out:
# 8250.7109375
# 0.046875

# %%
L = [1,2,3] #iterable
type(iter(L)) #iterator
# Out:
# list_iterator

# %%
#Every iterator is iterable
#Not all iterables are iterators

dir(L)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir(iter(L))
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__length_hint__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
print(iter(L))
# Out:
# <list_iterator object at 0x7b35d48ad0c0>

# %%
#Understanding how for loop works
num = [1,2,3]
#fetches the iterator
iter_num = iter(num)

#step 2 --> next
next(iter_num)
next(iter_num)
next(iter_num)
#next(iter_num)
# Out:
# 3

# %% [markdown]
# Making our own for loop

# %%
from typing_extensions import Iterator
def mera_forloop(iterable):
  iter = iter(iterable)
  while True:

    try:
      print(next(iter))
    except StopIteration:
      break

# %%
a = iter(L)
id(a)
# Out:
# 135470590260272

# %%
id(iter(a))
# Out:
# 135470590260272

# %%
x = range(1,11)
print(type(x))
type(iter(x))
# Out:
# <class 'range'>
# range_iterator

# %% [markdown]
# Python generators are a simple way of creating iterators

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def gen_demo():

  yield "fIRST"
  yield "SECOND"
  yield "THIRD"

# %%
gen = gen_demo()
for i in gen:
  print(i)
# Out:
# fIRST
# SECOND
# THIRD

# %%
def square(num):
  for i in range(1,num+1):
    yield i**2

# %%
gen = square(10)
print(next(gen
           ))
# Out:
# 1

# %%
for i in gen:
  print(i)
# Out:
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %%
def mera_range(start,end):
  for i in range(start,end):
    yield i

# %%
for i in mera_range(15,24):
  print(i
        )
# Out:
# 15
# 16
# 17
# 18
# 19
# 20
# 21
# 22
# 23

# %%
for i in range(1,4):
  print(i)
# Out:
# 1
# 2
# 3

# %%
gen = (i**2 for i in range(1,101))

# %%
for i in gen:
  print(i)

# %%
def all_even():
  n = 0
  while True:
    yield n
    n+=2

# %%
even_num_gen = all_even()
print(next(even_num_gen))
print(next(even_num_gen))
# Out:
# 0
# 2

# %%
#Chaining generators
def fib(nums):
  x,y = 0,1
  for i in range(nums):
    x,y = y, x+y
    yield x
def square(nums):
  for num in nums:
    yield num**2

print(sum(square(fib(10))))
# Out:
# 4895
