# %%
# !pip install opencv-python
import cv2
import numpy as np
# Out:
# Requirement already satisfied: opencv-python in c:\users\avinash\anaconda3\lib\site-packages (5.0.0.93)
# Requirement already satisfied: numpy>=2 in c:\users\avinash\anaconda3\lib\site-packages (from opencv-python) (2.3.5)

# %%
#Read an image
img = cv2.imread(r'C:\Users\AVINASH\Downloads\after_school_stroll_gruvbox.png')

# %%
img
# Out:
# array([[[136, 133,  69],
#         [136, 133,  69],
#         [136, 133,  69],
#         ...,
#         [136, 133,  69],
#         [136, 133,  69],
#         [136, 133,  69]],
#
#        [[136, 133,  69],
#         [136, 133,  69],
#         [136, 133,  69],
#         ...,
#         [136, 133,  69],
#         [136, 133,  69],
#         [136, 133,  69]],
#
#        [[136, 133,  69],
#         [106, 157, 104],
#         [136, 133,  69],
#         ...,
#         [ 69,  73,  80],
#         [136, 133,  69],
#         [136, 133,  69]],
#
#        ...,
#
#        [[ 64,  52,  46],
#         [ 64,  52,  46],
#         [ 64,  52,  46],
#         ...,
#         [155, 134, 211],
#         [ 47, 189, 250],
#         [155, 134, 211]],
#
#        [[ 33,  32,  29],
#         [ 64,  52,  46],
#         [ 64,  52,  46],
#         ...,
#         [155, 134, 211],
#         [ 25, 128, 243],
#         [155, 134, 211]],
#
#        [[ 64,  52,  46],
#         [ 64,  52,  46],
#         [ 64,  52,  46],
#         ...,
#         [ 25, 128, 243],
#         [ 47, 189, 250],
#         [155, 134, 211]]], shape=(1548, 3000, 3), dtype=uint8)

# %%
img.shape
# Out:
# (1548, 3000, 3)

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow('Image Window', img_gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_gray.shape
# Out:
# (1548, 3000)

# %% [markdown]
# # Playing with RGB color channels

# %%
img.shape
# Out:
# (1548, 3000, 3)

# %%
img1 = img[:,:,0] = 0
img2 = img[:,:,1] = 0
img3 = img[:,:,2] = 0

# %%
cv2_imshow(img)

# %%
new_img = np.hstack((img1,img2,img3))

# %%
cv2_imshow(new_img)

# %%
img_resize = cv2.resize(img, (img.shape[1]//4,img.shape[0]//4))

# %%
cv2_imshow(img_resize)

# %%
img_flip = cv2.flip(img, 1)
cv2_imshow(img_flip)

# %%
img_crop = img[0:600, 0:500]
cv2_imshow(img_crop)

# %%
cv2.imwrite('cropped_image.png',img_crop)

# %% [markdown]
# Image processing

# %%
img = np.zeros((512,512,3), np.uint8)

# %%
cv2.imshow('Image Window',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#rectangle
cv2.rectangle(img, (100,100), (300,300), (0,255,0), -1)
cv2.imshow('Image Window',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.circle(img, (400,50), 30, (255,255,0), 5)
cv2.imshow('Image Window',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.line(img, (0,0), (img.shape[1], img.shape[0]), (255,255,255), 3)
cv2.imshow('Image Window',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.putText(img, 'OpenCV', (300,200), cv2.FONT_HERSHEY_COMPLEX, 1, (0,150,0), 1)
cv2.imshow('Image Window',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = np.zeros((512,512,3),np.uint8)
def draw(event,x,y,flags,params):
    if event == 1:
        cv2.circle(img,center = (x,y),radius = 50, color = (0,0,255), thickness = -1)

cv2.namedWindow(winname = 'window')
cv2.setMouseCallback('window',draw)

while True:
    cv2.imshow('window' , img)
    if cv2.waitKey(1) & 0xFF == ord('x'):
        break
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

img = np.zeros((512, 512, 3), np.uint8)
drawing = False
ix = -1
iy = -1

def draw(event, x, y, flags, params):
    global drawing, ix, iy

    if event == 1:
        drawing = True
        ix = x
        iy = y

    elif event == 0:
        if drawing:
            cv2.rectangle(img, pt1=(ix, iy), pt2=(x, y), color=(0, 255, 255), thickness=-1)

    elif event == 4:
        drawing = False
        cv2.rectangle(img, pt1=(ix, iy), pt2=(x, y), color=(0, 255, 255), thickness=-1)

cv2.namedWindow(winname='window')
cv2.setMouseCallback('window', draw)

while True:
    cv2.imshow('window', img)
    if cv2.waitKey(1) & 0xFF == ord('x'):
        break

cv2.destroyAllWindows()

# %%
img = cv2.imread(r'C:\Users\AVINASH\Downloads\after_school_stroll_gruvbox.png')

# %%
flag = False
ix = -1
iy = -1

def crop(event,x,y,flags,params):
    global flag,ix,iy
    
    if event == 1:
        flag = True
        ix = x
        iy = y


    elif event ==4:
        fx = x
        fy = y
        flag = False
        cv2.rectangle(img, pt1=(ix, iy), pt2=(x, y), color=(0, 0, 0), thickness=1)

        cropped = img[iy:fy, ix:fx]
        cv2.imshow('new_window',cropped)
        cv2.waitKey(0)

# %%
cv2.namedWindow(winname = "window")
cv2.setMouseCallback("window",crop)

# %%
while True:

    cv2.imshow("window", img)

    if cv2.waitKey(1) & 0xFF == ord('x'):
        break
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[22], line 21, in crop(event, x, y, flags, params)
#      18 cv2.rectangle(img, pt1=(ix, iy), pt2=(x, y), color=(0, 0, 0), thickness=1)
#      20 cropped = img[iy:fy, ix:fx]
# ---> 21 cv2.imshow('new_window',cropped)
#      22 cv2.waitKey(0)
#
# error: OpenCV(5.0.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:951: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
cap = cv2.VideoCapture(0)
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.avi',fourcc,20.0,(640,480))

while True:
    
    ret, frame = cap.read()
    out.write(frame)
    
    img_gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    cv2.flip(img_gray,1)
    cv2.imshow('webcam',img_gray)
    
    

    if cv2.waitKey(1) & 0xFF == ord('x'):
        break
out.release()
cv2.destroyAllWindows()

# %%
import time

cap =cv2.VideoCapture('output.avi')
while True:
    
    ret, frame = cap.read()
    
    img_gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    time.sleep(1/20)
    cv2.flip(img_gray,1)
    cv2.imshow('webcam',img_gray)
    
    

    if cv2.waitKey(1) & 0xFF == ord('x'):
        break
        
cv2.destroyAllWindows()
