# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv('/content/imdb-top-1000.csv')
# Convert 'Released_Year' and 'Metascore' to numeric, coercing errors to NaN
movies['Released_Year'] = pd.to_numeric(movies['Released_Year'], errors='coerce')
movies['Metascore'] = pd.to_numeric(movies['Metascore'], errors='coerce')

# %%
movies.shape
# Out:
# (1000, 10)

# %%
genres = movies.groupby('Genre')

# %%
genres

# %%
genres.sum()
# Out:
#                                                 Series_Title  Released_Year  \
# Genre
# Action     The Dark KnightThe Lord of the Rings: The Retu...       343498.0
# Adventure  InterstellarBack to the FutureInglourious Bast...       141038.0
# Animation  Sen to Chihiro no kamikakushiThe Lion KingHota...       164182.0
# Biography  Schindler's ListGoodfellasHamiltonThe Intoucha...       175858.0
# Comedy     GisaengchungLa vita è bellaModern TimesCity Li...       307916.0
# Crime      The GodfatherThe Godfather: Part II12 Angry Me...       212868.0
# Drama      The Shawshank RedemptionFight ClubForrest Gump...       574806.0
# Family     E.T. the Extra-TerrestrialWilly Wonka & the Ch...         3953.0
# Fantasy                Das Cabinet des Dr. CaligariNosferatu         3842.0
# Film-Noir   The Third ManThe Maltese FalconShadow of a Doubt         5833.0
# Horror     PsychoAlienThe ThingThe ExorcistNight of the L...        21756.0
# ...

# %%
genres.min()
# Out:
#                               Series_Title  Released_Year  Runtime  \
# Genre
# Action                                 300         1924.0       45
# Adventure            2001: A Space Odyssey         1925.0       88
# Animation                            Akira         1940.0       71
# Biography                 12 Years a Slave         1928.0       93
# Comedy                (500) Days of Summer         1921.0       68
# Crime                         12 Angry Men         1931.0       80
# Drama                                 1917         1925.0       64
# Family          E.T. the Extra-Terrestrial         1971.0      100
# Fantasy       Das Cabinet des Dr. Caligari         1920.0       76
# Film-Noir                Shadow of a Doubt         1941.0      100
# Horror                               Alien         1933.0       71
# Mystery                          Dark City         1938.0       96
# Thriller                   Wait Until Dark         1967.0      108
# ...

# %%
#find top 3 genres by total earning
movies.groupby('Genre').sum().sort_values(by='Gross', ascending=False).head(3)
# Out:
#                                              Series_Title  Released_Year  \
# Genre
# Drama   The Shawshank RedemptionFight ClubForrest Gump...       574806.0
# Action  The Dark KnightThe Lord of the Rings: The Retu...       343498.0
# Comedy  GisaengchungLa vita è bellaModern TimesCity Li...       307916.0
#
#         Runtime  IMDB_Rating  \
# Genre
# Drama     36049       2299.7
# Action    22196       1367.3
# Comedy    17380       1224.7
#
#                                                  Director  \
# Genre
# Drama   Frank DarabontDavid FincherRobert ZemeckisMilo...
# Action  Christopher NolanPeter JacksonChristopher Nola...
# Comedy  Bong Joon HoRoberto BenigniCharles ChaplinChar...
#
#                                                     Star1  No_of_Votes  \
# Genre
# Drama   Tim RobbinsBrad PittTom HanksJack NicholsonSur...     61367304
# Action  Christian BaleElijah WoodLeonardo DiCaprioElij...     72282412
# ...

# %%
movies.groupby('Genre')['Gross'].sum().sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
movies.groupby('Genre')['IMDB_Rating'].mean().sort_values(ascending=False).head(3)
# Out:
# Genre
# Western    8.350000
# Crime      8.016822
# Fantasy    8.000000
# Name: IMDB_Rating, dtype: float64

# %%
movies.groupby('Director')['No_of_Votes'].sum().sort_values(ascending=False).head(3)
# Out:
# Director
# Christopher Nolan    11578345
# Quentin Tarantino     8123208
# Steven Spielberg      7817166
# Name: No_of_Votes, dtype: int64

# %%
movies.groupby('Genre')['IMDB_Rating'].max().sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     9.3
# Crime     9.2
# Action    9.0
# Name: IMDB_Rating, dtype: float64

# %%
movies.groupby('Star1')['Series_Title'].count().sort_values(ascending=False)
# Out:
# Star1
# Tom Hanks            12
# Robert De Niro       11
# Clint Eastwood       10
# Al Pacino            10
# Leonardo DiCaprio     9
#                      ..
# Gérard Jugnot         1
# Günes Sensoy          1
# Haluk Bilginer        1
# Harriet Andersson     1
# Graham Chapman        1
# Name: Series_Title, Length: 660, dtype: int64

# %%
movies.groupby('Star1')['Series_Title'].value_counts()
# Out:
# Star1                 Series_Title
# Aamir Khan            3 Idiots                             1
#                       Andaz Apna Apna                      1
#                       Dangal                               1
#                       Dil Chahta Hai                       1
#                       Lagaan: Once Upon a Time in India    1
#                                                           ..
# Zbigniew Zamachowski  Trois couleurs: Blanc                1
# Zooey Deschanel       (500) Days of Summer                 1
# Çetin Tekindor        Babam ve Oglum                       1
# Éric Toledano         The Intouchables                     1
# Ömer Faruk Sorak      Vizontele                            1
# Name: count, Length: 1000, dtype: int64

# %%
len(movies.groupby('Genre'))
# Out:
# 14

# %%
movies.groupby('Genre').size()
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64

# %%
genres = movies.groupby('Genre')
print(genres.last())
# Out:
#                                   Series_Title  Released_Year  Runtime  \
# Genre
# Action                    Escape from Alcatraz         1979.0      112
# Adventure                       Kelly's Heroes         1970.0      144
# Animation                      The Jungle Book         1967.0       78
# Biography                     Midnight Express         1978.0      121
# Comedy                  Breakfast at Tiffany's         1961.0      115
# Crime                             The 39 Steps         1935.0       86
# Drama                                 Lifeboat         1944.0       97
# Family     Willy Wonka & the Chocolate Factory         1971.0      100
# Fantasy                              Nosferatu         1922.0       94
# Film-Noir                    Shadow of a Doubt         1943.0      108
# Horror                              The Others         2001.0      101
# Mystery                           Lost Highway         1997.0      134
# ...

# %%
genres.nth(7)
# Out:
#                  Series_Title  Released_Year  Runtime      Genre  IMDB_Rating  \
# 28   The Silence of the Lambs         1991.0      118      Crime          8.6
# 29                  Star Wars         1977.0      121     Action          8.6
# 34                   Whiplash         2014.0      106      Drama          8.5
# 70              Mononoke-hime         1997.0      134  Animation          8.4
# 95                     Amélie         2001.0      122     Comedy          8.3
# 107                   Amadeus         1984.0      160  Biography          8.3
# 137                     Queen         2013.0      146  Adventure          8.2
# 714         The Lady Vanishes         1938.0       96    Mystery          7.8
# 844                 Halloween         1978.0       91     Horror          7.7
#
#                Director              Star1  No_of_Votes        Gross  \
# 28       Jonathan Demme       Jodie Foster      1270197  130742922.0
# ...

# %%
genres.get_group('Horror')
# Out:
#                  Series_Title  Released_Year  Runtime   Genre  IMDB_Rating  \
# 49                     Psycho         1960.0      109  Horror          8.5
# 75                      Alien         1979.0      117  Horror          8.4
# 271                 The Thing         1982.0      109  Horror          8.1
# 419              The Exorcist         1973.0      122  Horror          8.0
# 544  Night of the Living Dead         1968.0       96  Horror          7.9
# 707             The Innocents         1961.0      100  Horror          7.8
# 724                   Get Out         2017.0      104  Horror          7.7
# 844                 Halloween         1978.0       91  Horror          7.7
# 876         The Invisible Man         1933.0       71  Horror          7.7
# 932                       Saw         2004.0      103  Horror          7.6
# 948                The Others         2001.0      101  Horror          7.6
#
# ...

# %%
genres.groups
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
genres.describe()
# Out:
#           Released_Year                                                   \
#                   count         mean        std     min      25%     50%
# Genre
# Action            172.0  1997.081395  20.350275  1924.0  1986.75  2004.0
# Adventure          71.0  1986.450704  24.841664  1925.0  1968.00  1990.0
# Animation          82.0  2002.219512  13.638204  1940.0  1994.25  2004.0
# Biography          88.0  1998.386364  17.615583  1928.0  1989.00  2004.0
# Comedy            155.0  1986.554839  25.396119  1921.0  1972.50  1993.0
# Crime             107.0  1989.420561  22.303243  1931.0  1972.50  1996.0
# Drama             289.0  1988.948097  24.446812  1925.0  1969.00  1997.0
# Family              2.0  1976.500000   7.778175  1971.0  1973.75  1976.5
# Fantasy             2.0  1921.000000   1.414214  1920.0  1920.50  1921.0
# Film-Noir           3.0  1944.333333   4.163332  1941.0  1942.00  1943.0
# Horror             11.0  1977.818182  23.464092  1933.0  1964.50  1978.0
# ...

# %%
genres.sample(2, replace = True)
# Out:
#                             Series_Title  Released_Year  Runtime      Genre  \
# 784                     The Last Samurai         2003.0      154     Action
# 368                        Casino Royale         2006.0      144     Action
# 406                   The Princess Bride         1987.0       98  Adventure
# 415                                 Jaws         1975.0      124  Adventure
# 758                             Papurika         2006.0       90  Animation
# 828              Who Framed Roger Rabbit         1988.0      104  Animation
# 173                          Raging Bull         1980.0      129  Biography
# 290                        Andrei Rublev         1966.0      205  Biography
# 816                               Clerks         1994.0       92     Comedy
# 752              Silver Linings Playbook         2012.0      122     Comedy
# 28              The Silence of the Lambs         1991.0      118      Crime
# ...

# %%
genres.sum()
# Out:
#                                                 Series_Title  Released_Year  \
# Genre
# Action     The Dark KnightThe Lord of the Rings: The Retu...       343498.0
# Adventure  InterstellarBack to the FutureInglourious Bast...       141038.0
# Animation  Sen to Chihiro no kamikakushiThe Lion KingHota...       164182.0
# Biography  Schindler's ListGoodfellasHamiltonThe Intoucha...       175858.0
# Comedy     GisaengchungLa vita è bellaModern TimesCity Li...       307916.0
# Crime      The GodfatherThe Godfather: Part II12 Angry Me...       212868.0
# Drama      The Shawshank RedemptionFight ClubForrest Gump...       574806.0
# Family     E.T. the Extra-TerrestrialWilly Wonka & the Ch...         3953.0
# Fantasy                Das Cabinet des Dr. CaligariNosferatu         3842.0
# Film-Noir   The Third ManThe Maltese FalconShadow of a Doubt         5833.0
# Horror     PsychoAlienThe ThingThe ExorcistNight of the L...        21756.0
# ...

# %% [markdown]
# Aggregation functions

# %%
genres.agg(
    {
        'Runtime':['mean','min','max'],
        'Gross':'sum',
        'IMDB_Rating':'mean',
        'No_of_Votes':'sum',
        'Metascore':'min'
    }
)
# Out:
#               Runtime                   Gross IMDB_Rating No_of_Votes  \
#                  mean  min  max           sum        mean         sum
# Genre
# Action     129.046512   45  321  3.263226e+10    7.949419    72282412
# Adventure  134.111111   88  228  9.496922e+09    7.937500    22576163
# Animation   99.585366   71  137  1.463147e+10    7.930488    21978630
# Biography  136.022727   93  209  8.276358e+09    7.938636    24006844
# Comedy     112.129032   68  188  1.566387e+10    7.901290    27620327
# Crime      126.392523   80  229  8.452632e+09    8.016822    33533615
# Drama      124.737024   64  242  3.540997e+10    7.957439    61367304
# Family     107.500000  100  115  4.391106e+08    7.800000      551221
# Fantasy     85.000000   76   94  7.827267e+08    8.000000      146222
# Film-Noir  104.000000  100  108  1.259105e+08    7.966667      367215
# Horror     102.090909   71  122  1.034649e+09    7.909091     3742556
# ...

# %% [markdown]
# Passing List

# %%
genres[['Released_Year', 'Runtime', 'IMDB_Rating', 'No_of_Votes', 'Gross', 'Metascore']].agg(['min','max','mean'])
# Out:
#           Released_Year                      Runtime                   \
#                     min     max         mean     min  max        mean
# Genre
# Action           1924.0  2019.0  1997.081395      45  321  129.046512
# Adventure        1925.0  2019.0  1986.450704      88  228  134.111111
# Animation        1940.0  2020.0  2002.219512      71  137   99.585366
# Biography        1928.0  2020.0  1998.386364      93  209  136.022727
# Comedy           1921.0  2020.0  1986.554839      68  188  112.129032
# Crime            1931.0  2019.0  1989.420561      80  229  126.392523
# Drama            1925.0  2020.0  1988.948097      64  242  124.737024
# Family           1971.0  1982.0  1976.500000     100  115  107.500000
# Fantasy          1920.0  1922.0  1921.000000      76   94   85.000000
# Film-Noir        1941.0  1949.0  1944.333333     100  108  104.000000
# Horror           1933.0  2017.0  1977.818182      71  122  102.090909
# ...

# %%
#looping on groups
genres

# %%
df = pd.DataFrame()

for group, data in genres:
    top_movies = data[data['IMDB_Rating'] == data['IMDB_Rating'].max()]
    df = pd.concat([df, top_movies])

df
# Out:
#                             Series_Title  Released_Year  Runtime      Genre  \
# 2                        The Dark Knight         2008.0      152     Action
# 21                          Interstellar         2014.0      169  Adventure
# 23         Sen to Chihiro no kamikakushi         2001.0      125  Animation
# 7                       Schindler's List         1993.0      195  Biography
# 19                          Gisaengchung         2019.0      132     Comedy
# 26                       La vita è bella         1997.0      116     Comedy
# 1                          The Godfather         1972.0      175      Crime
# 0               The Shawshank Redemption         1994.0      142      Drama
# 688           E.T. the Extra-Terrestrial         1982.0      115     Family
# 698  Willy Wonka & the Chocolate Factory         1971.0      100     Family
# 321         Das Cabinet des Dr. Caligari         1920.0       76    Fantasy
# ...

# %%
#split (apply) combine stratergy
genres.apply(min)
# Out:
# /tmp/ipykernel_4013/3284641627.py:2: FutureWarning: The provided callable <built-in function min> is currently using np.minimum.reduce. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string np.minimum.reduce instead.
#   genres.apply(min)
# /tmp/ipykernel_4013/3284641627.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(min)
#                               Series_Title  Released_Year  Runtime      Genre  \
# Genre
# Action                                 300         1924.0       45     Action
# Adventure            2001: A Space Odyssey            NaN       88  Adventure
# ...

# %%
def foo(group):
  return group['Series_Title'].str.startswith('A').sum()

# %%
genres.apply(foo)
# Out:
# /tmp/ipykernel_4013/2904676014.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(foo)
# Genre
# Action       10
# Adventure     2
# Animation     2
# Biography     9
# Comedy       14
# Crime         4
# Drama        21
# Family        0
# Fantasy       0
# Film-Noir     0
# Horror        1
# Mystery       0
# Thriller      0
# Western       0
# dtype: int64

# %%
#find ranking of eacg movie in the group according to IMDB score
def rank_movie(group):
  group['genre_rank']=group['IMDB_Rating'].rank(ascending=False)
  return group

# %%
genres.apply(rank_movie)
# Out:
# /tmp/ipykernel_4013/2409710219.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(rank_movie)
#                                                    Series_Title  \
# Genre
# Action   2                                      The Dark Knight
#          5        The Lord of the Rings: The Return of the King
#          8                                            Inception
#          10   The Lord of the Rings: The Fellowship of the Ring
#          13               The Lord of the Rings: The Two Towers
# ...                                                         ...
# Thriller 700                                    Wait Until Dark
# ...

# %%
def normal(group):
  group['norm_rating'] = (group['IMDB_Rating'] - group['IMDB_Rating'].min()) / (group['IMDB_Rating'].max() - group['IMDB_Rating'].min())
  return group

genres.apply(normal)
# Out:
# /tmp/ipykernel_4013/3223270457.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(normal)
#                                                    Series_Title  \
# Genre
# Action   2                                      The Dark Knight
#          5        The Lord of the Rings: The Return of the King
#          8                                            Inception
#          10   The Lord of the Rings: The Fellowship of the Ring
#          13               The Lord of the Rings: The Two Towers
# ...                                                         ...
# Thriller 700                                    Wait Until Dark
# ...

# %%
duo = movies.groupby(['Director','Star1'])
duo

duo.size()
# Out:
# Director             Star1
# Aamir Khan           Amole Gupte       1
# Aaron Sorkin         Eddie Redmayne    1
# Abdellatif Kechiche  Léa Seydoux       1
# Abhishek Chaubey     Shahid Kapoor     1
# Abhishek Kapoor      Amit Sadh         1
#                                       ..
# Zaza Urushadze       Lembit Ulfsak     1
# Zoya Akhtar          Hrithik Roshan    1
#                      Vijay Varma       1
# Çagan Irmak          Çetin Tekindor    1
# Ömer Faruk Sorak     Cem Yilmaz        1
# Length: 898, dtype: int64

# %%
duo['Gross'].sum().sort_values(ascending=False)
# Out:
# Director              Star1
# Akira Kurosawa        Toshirô Mifune     2.999877e+09
# Anthony Russo         Joe Russo          2.205039e+09
# Billy Wilder          William Holden     1.286779e+09
# Christopher Nolan     Christian Bale     1.242940e+09
# Werner Herzog         Klaus Kinski       1.124605e+09
#                                              ...
# Jeong-beom Lee        Won Bin            6.460000e+03
# Shane Meadows         Paddy Considine    6.013000e+03
# Jaco Van Dormael      Jared Leto         3.600000e+03
# Thomas Jahn           Til Schweiger      3.296000e+03
# Anders Thomas Jensen  Ulrich Thomsen     1.305000e+03
# Name: Gross, Length: 898, dtype: float64

# %%
actgen = movies.groupby(['Star1','Genre'])
actgen['Metascore'].mean().reset_index().sort_values(by='Metascore', ascending=False)
# Out:
#                 Star1      Genre  Metascore
# 606     Peter O'Toole  Adventure      100.0
# 590      Orson Welles      Drama      100.0
# 77        Bertil Guve      Drama      100.0
# 230    Ellar Coltrane      Drama      100.0
# 329   Humphrey Bogart      Drama      100.0
# ..                ...        ...        ...
# 807    William Holden      Drama        NaN
# 812           Won Bin     Action        NaN
# 815              Yash     Action        NaN
# 826    Çetin Tekindor      Drama        NaN
# 828  Ömer Faruk Sorak     Comedy        NaN
#
# [829 rows x 3 columns]

# %%
duo[['Released_Year', 'Runtime', 'IMDB_Rating', 'No_of_Votes', 'Gross', 'Metascore']].agg(['min','max','mean'])
# Out:
#                                    Released_Year                 Runtime       \
#                                              min     max    mean     min  max
# Director            Star1
# Aamir Khan          Amole Gupte           2007.0  2007.0  2007.0     165  165
# Aaron Sorkin        Eddie Redmayne        2020.0  2020.0  2020.0     129  129
# Abdellatif Kechiche Léa Seydoux           2013.0  2013.0  2013.0     180  180
# Abhishek Chaubey    Shahid Kapoor         2016.0  2016.0  2016.0     148  148
# Abhishek Kapoor     Amit Sadh             2013.0  2013.0  2013.0     130  130
# ...                                          ...     ...     ...     ...  ...
# Zaza Urushadze      Lembit Ulfsak         2013.0  2013.0  2013.0      87   87
# Zoya Akhtar         Hrithik Roshan        2011.0  2011.0  2011.0     155  155
#                     Vijay Varma           2019.0  2019.0  2019.0     154  154
# Çagan Irmak         Çetin Tekindor        2005.0  2005.0  2005.0     112  112
# ...

# %% [markdown]
# EXERCISE

# %%
ipl = pd.read_csv('deliveries.csv')

# %%
ipl.shape
# Out:
# (179078, 21)

# %%
ipl.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
ipl.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(10)
# Out:
# batsman
# V Kohli           5434
# SK Raina          5415
# RG Sharma         4914
# DA Warner         4741
# S Dhawan          4632
# CH Gayle          4560
# MS Dhoni          4477
# RV Uthappa        4446
# AB de Villiers    4428
# G Gambhir         4223
# Name: batsman_runs, dtype: int64

# %%
ipl[ipl['batsman_runs'] == 6].groupby('batsman')['ball'].count().sort_values(ascending=False)
# Out:
# batsman
# CH Gayle          327
# AB de Villiers    214
# MS Dhoni          207
# SK Raina          195
# RG Sharma         194
#                  ...
# AN Ahmed            1
# AD Mascarenhas      1
# TA Boult            1
# T Kohli             1
# TS Mills            1
# Name: ball, Length: 336, dtype: int64

# %%
temp_df =ipl[ipl['over']>15]
temp_df = temp_df[(temp_df['batsman_runs'] == 4) | (temp_df['batsman_runs'] == 6)]
temp_df.groupby('batsman')['batsman'].count().sort_values(ascending=False)
# Out:
# batsman
# MS Dhoni          340
# RG Sharma         208
# AB de Villiers    208
# KA Pollard        206
# V Kohli           160
#                  ...
# AR Bawne            1
# TS Mills            1
# TA Boult            1
# T Taibu             1
# T Curran            1
# Name: batsman, Length: 360, dtype: int64

# %%
temp_df = ipl[ipl['batsman']== 'V Kohli']
temp_df.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending=False)
# Out:
# bowling_team
# Delhi Daredevils           763
# Chennai Super Kings        749
# Kolkata Knight Riders      675
# Kings XI Punjab            636
# Mumbai Indians             628
# Sunrisers Hyderabad        509
# Rajasthan Royals           370
# Deccan Chargers            306
# Gujarat Lions              283
# Rising Pune Supergiants    188
# Pune Warriors              128
# Rising Pune Supergiant      83
# Delhi Capitals              66
# Kochi Tuskers Kerala        50
# Name: batsman_runs, dtype: int64

# %%
temp_df = ipl[ipl['batsman']== 'V Kohli']
temp_df.groupby('match_id')['batsman_runs'].sum().sort_values(ascending=False)
# Out:
# match_id
# 626      113
# 620      109
# 611      108
# 595      100
# 11326    100
#         ...
# 27         0
# 488        0
# 481        0
# 462        0
# 633        0
# Name: batsman_runs, Length: 169, dtype: int64

# %%
def highest(batsman):
  temp_df = ipl[ipl['batsman']== batsman]
  return temp_df.groupby('match_id')['batsman_runs'].sum().sort_values(ascending=False).head(1).values[0]

# %%
highest('AB de Villiers')
# Out:
# np.int64(133)

# %% [markdown]
# Session 20

# %%
import pandas as pd
import numpy as np
students = pd.read_csv('students.csv')
courses = pd.read_csv('courses.csv')
nov = pd.read_csv('reg-month1.csv')
dec = pd.read_csv('reg-month2.csv')
mathches = pd.read_csv('matches.csv')
delivery = pd.read_csv('deliveries.csv')

# %%
#pd.concat
regs =pd.concat([nov,dec],ignore_index=True)

# %%
nov.append(dec, ignore_index=True) #error throw
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_950/1576424983.py in <cell line: 0>()
# ----> 1 nov.append(dec, ignore_index=True) #error throw
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
multi = pd.concat([nov,dec],keys = ['Nov','Dec'])
#MultiIndex DataFrame

# %%
multi.loc['Nov'].iloc[0::2]
# Out:
#     student_id  course_id
# 0           23          1
# 2           18          6
# 4           16          9
# 6            1          1
# 8           22          3
# 10          19          4
# 12           7         10
# 14          13          3
# 16          21          1
# 18          23          3
# 20          23          6
# 22          19          2
# 24           3          3

# %%
multi.loc[('Dec',4)]
# Out:
# student_id    14
# course_id      9
# Name: (Dec, 4), dtype: int64

# %%
pd.concat([nov,dec],axis= 1).shape
# Out:
# (28, 4)

# %%
#inner join

students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
students.merge(regs, how = 'inner', on = 'student_id')
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo       23          1
# 1            1       Kailash Harjo       23          6
# 2            1       Kailash Harjo       23         10
# 3            1       Kailash Harjo       23          9
# 4            2         Esha Butala        1          5
# 5            3      Parveen Bhalla        3          3
# 6            3      Parveen Bhalla        3          5
# 7            7        Tarun Thaker        9          8
# 8            7        Tarun Thaker        9         10
# 9            7        Tarun Thaker        9          7
# 10           7        Tarun Thaker        9          2
# 11           7        Tarun Thaker        9          6
# 12          11  David Mukhopadhyay       20          7
# 13          11  David Mukhopadhyay       20          8
# 14          11  David Mukhopadhyay       20         10
# 15          12          Radha Dutt       19         10
# ...

# %%
#left join

courses.merge(regs, how = 'left', on = 'course_id')
# Out:
#     course_id       course_name  price  student_id
# 0           1            python   2499        23.0
# 1           1            python   2499        18.0
# 2           1            python   2499         1.0
# 3           1            python   2499        15.0
# 4           1            python   2499        21.0
# 5           1            python   2499        25.0
# 6           1            python   2499        12.0
# 7           1            python   2499        14.0
# 8           1            python   2499        38.0
# 9           2               sql   3499        19.0
# 10          2               sql   3499         7.0
# 11          3     data analysis   4999        22.0
# 12          3     data analysis   4999        13.0
# 13          3     data analysis   4999        23.0
# 14          3     data analysis   4999         3.0
# 15          3     data analysis   4999        16.0
# 16          4  machine learning   9999        23.0
# ...

# %%
#right join
temp_df=pd.DataFrame({
    'student_id' :[26,27,28],
    'name':['Avinash','Adarsh','Anustup'],
    'partner' : [28,26,17]

})
students = pd.concat([students,temp_df],ignore_index = True)

# %%
students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
students.merge(regs, how = 'left', on = 'student_id')
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo       23        1.0
# 1            1       Kailash Harjo       23        6.0
# 2            1       Kailash Harjo       23       10.0
# 3            1       Kailash Harjo       23        9.0
# 4            2         Esha Butala        1        5.0
# 5            3      Parveen Bhalla        3        3.0
# 6            3      Parveen Bhalla        3        5.0
# 7            4         Marlo Dugal       14        NaN
# 8            5         Kusum Bahri        6        NaN
# 9            6  Lakshmi Contractor       10        NaN
# 10           7        Tarun Thaker        9        8.0
# 11           7        Tarun Thaker        9       10.0
# 12           7        Tarun Thaker        9        7.0
# 13           7        Tarun Thaker        9        2.0
# 14           7        Tarun Thaker        9        6.0
# 15           8      Radheshyam Dey        5        NaN
# ...

# %%
students.merge(regs, how = 'outer', on = 'student_id').tail(10)
# Out:
#     student_id             name  partner  course_id
# 53          23   Chhavi Lachman     18.0        5.0
# 54          24     Radhika Suri     17.0        4.0
# 55          25  Shashank D’Alia      2.0        1.0
# 56          25  Shashank D’Alia      2.0       10.0
# 57          26          Avinash     28.0        NaN
# 58          27           Adarsh     26.0        NaN
# 59          28          Anustup     17.0        NaN
# 60          38              NaN      NaN        1.0
# 61          42              NaN      NaN        9.0
# 62          50              NaN      NaN        8.0

# %%
#find total revenue generated by the company
regs
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# ...

# %%
students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
regs.merge(courses, how ='inner', on='course_id')['price'].sum()
# Out:
# np.int64(154247)

# %%
regs.merge(courses, how ='inner', on='course_id').groupby('course_id')['price'].sum()
# Out:
# course_id
# 1     22491
# 2      6998
# 3     24995
# 4     39996
# 5     17493
# 6     11394
# 7      7995
# 8      4396
# 9      3495
# 10    14994
# Name: price, dtype: int64

# %%
#2 find month by month revenue
temp_df = pd.concat([nov,dec],keys = ['Nov','Dec']).reset_index()
temp_df.merge(courses, how ='inner', on='course_id').groupby(['level_0'])['price'].sum()
# Out:
# level_0
# Dec    65072
# Nov    89175
# Name: price, dtype: int64

# %%
#Print cols-> name -> price
regs.merge(students, how ='inner', on='student_id').merge(courses, how ='inner', on='course_id')[['name','course_name','price']]
# Out:
#                   name       course_name  price
# 0       Chhavi Lachman            python   2499
# 1            Preet Sha           tableau   2499
# 2      Fardeen Mahabir          power bi   1899
# 3       Chhavi Lachman  machine learning   9999
# 4         Elias Dodiya            plotly    699
# 5      Fardeen Mahabir            python   2499
# 6        Kailash Harjo            python   2499
# 7         Tarun Thaker            pandas   1099
# 8           Yash Sethi     data analysis   4999
# 9            Preet Sha            python   2499
# 10        Qabeel Raman  machine learning   9999
# 11       Kailash Harjo          power bi   1899
# 12        Tarun Thaker           pyspark   2499
# 13  David Mukhopadhyay          ms sxcel   1599
# 14      Munni Varghese     data analysis   4999
# 15        Radhika Suri  machine learning   9999
# 16          Seema Kota            python   2499
# 17        Elias Dodiya           tableau   2499
# 18      Chhavi Lachman     data analysis   4999
# ...

# %%
#Plot bar chart for revenue/course

regs.merge(courses, how ='inner', on='course_id').groupby('course_name')['price'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='course_name'>

# %%
common_student_id = nov.merge(dec, on ='student_id')['student_id'].unique()

# %%
common_student_id
# Out:
# array([23, 18, 16,  1,  7, 22, 11, 17,  3])

# %%
students[students['student_id'].isin(common_student_id)]
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 2            3      Parveen Bhalla        3
# 6            7        Tarun Thaker        9
# 10          11  David Mukhopadhyay       20
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 21          22          Yash Sethi       21
# 22          23      Chhavi Lachman       18

# %%
#another way
common = np.intersect1d(nov['student_id'], dec['student_id'])

# %%
common
# Out:
# array([ 1,  3,  7, 11, 16, 17, 18, 22, 23])

# %%
course_id_list = np.setdiff1d(courses['course_id'],regs['course_id'])

# %%
courses[courses['course_id'].isin(course_id_list)]
# Out:
#     course_id course_name  price
# 10         11       Numpy    699
# 11         12         C++   1299

# %%
#self join
students.merge(students, how='inner', left_on = 'partner', right_on = 'student_id')[['name_x','name_y']]
# Out:
#                 name_x              name_y
# 0        Kailash Harjo      Chhavi Lachman
# 1          Esha Butala       Kailash Harjo
# 2       Parveen Bhalla      Parveen Bhalla
# 3          Marlo Dugal    Pranab Natarajan
# 4          Kusum Bahri  Lakshmi Contractor
# 5   Lakshmi Contractor      Aayushman Sant
# 6         Tarun Thaker   Nitika Chatterjee
# 7       Radheshyam Dey         Kusum Bahri
# 8    Nitika Chatterjee         Marlo Dugal
# 9       Aayushman Sant      Radheshyam Dey
# 10  David Mukhopadhyay       Hanuman Hegde
# 11          Radha Dutt        Qabeel Raman
# 12      Munni Varghese        Radhika Suri
# 13    Pranab Natarajan          Yash Sethi
# 14           Preet Sha        Elias Dodiya
# 15        Elias Dodiya     Shashank D’Alia
# 16        Yasmin Palan        Tarun Thaker
# 17     Fardeen Mahabir      Munni Varghese
# 18        Qabeel Raman          Radha Dutt
# 19       Hanuman Hegde  David Mukhopadhyay
# 20          Seema Kota           Preet Sha
# ...

# %%
students.merge(students, how='inner', left_on = 'partner', right_on = 'student_id')[['name_x','name_y']]
# Out:
#                 name_x              name_y
# 0        Kailash Harjo      Chhavi Lachman
# 1          Esha Butala       Kailash Harjo
# 2       Parveen Bhalla      Parveen Bhalla
# 3          Marlo Dugal    Pranab Natarajan
# 4          Kusum Bahri  Lakshmi Contractor
# 5   Lakshmi Contractor      Aayushman Sant
# 6         Tarun Thaker   Nitika Chatterjee
# 7       Radheshyam Dey         Kusum Bahri
# 8    Nitika Chatterjee         Marlo Dugal
# 9       Aayushman Sant      Radheshyam Dey
# 10  David Mukhopadhyay       Hanuman Hegde
# 11          Radha Dutt        Qabeel Raman
# 12      Munni Varghese        Radhika Suri
# 13    Pranab Natarajan          Yash Sethi
# 14           Preet Sha        Elias Dodiya
# 15        Elias Dodiya     Shashank D’Alia
# 16        Yasmin Palan        Tarun Thaker
# 17     Fardeen Mahabir      Munni Varghese
# 18        Qabeel Raman          Radha Dutt
# 19       Hanuman Hegde  David Mukhopadhyay
# 20          Seema Kota           Preet Sha
# ...

# %%
students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
#find top 3 students who did most number of enrollments
regs.merge(students, how ='inner', on='student_id').groupby('name')['student_id'].count().sort_values(ascending=False).head(3)
# Out:
# name
# Chhavi Lachman    6
# Tarun Thaker      5
# Radha Dutt        4
# Name: student_id, dtype: int64

# %%
#find top 3 students who did most number of enrollments
regs.merge(students, how ='inner', on='student_id').groupby(['name','student_id'])['name'].count().sort_values(ascending=False).head(3)
# Out:
# name            student_id
# Chhavi Lachman  23            6
# Tarun Thaker    7             5
# Radha Dutt      12            4
# Name: name, dtype: int64

# %%
students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
regs
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# ...

# %%
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
regs.merge(students, how ='inner', on='student_id').merge(courses,on ='course_id').groupby(['name','student_id','price'])['student_id'].count()#['price'].sum().sort_values(ascending=False)
# Out:
# name                student_id  price
# Chhavi Lachman      23          699      1
#                                 1899     1
#                                 2499     2
#                                 4999     1
#                                 9999     1
# David Mukhopadhyay  11          1099     1
#                                 1599     1
#                                 2499     1
# Elias Dodiya        16          699      1
#                                 1599     1
#                                 2499     1
#                                 4999     1
# Esha Butala         2           2499     1
# Fardeen Mahabir     18          1099     1
#                                 1899     1
#                                 2499     1
# Kailash Harjo       1           699      1
#                                 1899     1
#                                 2499     2
# Munni Varghese      13          4999     1
# Parveen Bhalla      3           2499     1
# ...

# %%
regs.merge(students, how ='inner', on='student_id').merge(courses,on ='course_id').groupby(['name','student_id'])['price'].sum().sort_values(ascending=False)
# Out:
# name                student_id
# Chhavi Lachman      23            22594
# Pranab Natarajan    14            15096
# Qabeel Raman        19            13498
# Tarun Thaker        7             10595
# Radhika Suri        24             9999
# Elias Dodiya        16             9796
# Yash Sethi          22             9397
# Radha Dutt          12             9096
# Kailash Harjo       1              7596
# Parveen Bhalla      3              7498
# Fardeen Mahabir     18             5497
# David Mukhopadhyay  11             5197
# Munni Varghese      13             4999
# Preet Sha           15             4998
# Shashank D’Alia     25             4998
# Yasmin Palan        17             4098
# Esha Butala         2              2499
# Seema Kota          21             2499
# Name: price, dtype: int64

# %%
#Alternate syntax for merge
students.join(regs.set_index('student_id'), on = 'student_id', how = 'inner')

pd.merge(students,regs, how ='inner', on='student_id')
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo       23          1
# 1            1       Kailash Harjo       23          6
# 2            1       Kailash Harjo       23         10
# 3            1       Kailash Harjo       23          9
# 4            2         Esha Butala        1          5
# 5            3      Parveen Bhalla        3          3
# 6            3      Parveen Bhalla        3          5
# 7            7        Tarun Thaker        9          8
# 8            7        Tarun Thaker        9         10
# 9            7        Tarun Thaker        9          7
# 10           7        Tarun Thaker        9          2
# 11           7        Tarun Thaker        9          6
# 12          11  David Mukhopadhyay       20          7
# 13          11  David Mukhopadhyay       20          8
# 14          11  David Mukhopadhyay       20         10
# 15          12          Radha Dutt       19         10
# ...

# %%
#find top 3 stadiums with highest sixes per match

matches = pd.read_csv('matches.csv')
delivery = pd.read_csv('deliveries.csv')

# %%
matches
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
delivery
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
temp_df=pd.merge(delivery,matches, how ='inner', left_on = 'match_id', right_on = 'id')

# %%
six_df = temp_df = temp_df[temp_df['batsman_runs'] >= 6]

# %%
#sixes per stadium

num_sixes = six_df.groupby('venue')['batsman_runs'].count().sort_values(ascending=False)

# %%
num_sixes
# Out:
# venue
# M Chinnaswamy Stadium                                   873
# Wankhede Stadium                                        657
# Feroz Shah Kotla                                        636
# Eden Gardens                                            594
# MA Chidambaram Stadium, Chepauk                         507
# Rajiv Gandhi International Stadium, Uppal               492
# Punjab Cricket Association Stadium, Mohali              307
# Sawai Mansingh Stadium                                  243
# Dr DY Patil Sports Academy                              173
# Maharashtra Cricket Association Stadium                 169
# Subrata Roy Sahara Stadium                              141
# Kingsmead                                               130
# Sardar Patel Stadium, Motera                            130
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     129
# SuperSport Park                                         120
# Brabourne Stadium                                       114
# ...

# %%
num_matches = matches['venue'].value_counts()

# %%
num_matches
# Out:
# venue
# M Chinnaswamy Stadium                                   66
# Eden Gardens                                            61
# Feroz Shah Kotla                                        60
# Wankhede Stadium                                        57
# Rajiv Gandhi International Stadium, Uppal               49
# MA Chidambaram Stadium, Chepauk                         48
# Punjab Cricket Association Stadium, Mohali              35
# Sawai Mansingh Stadium                                  33
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# Maharashtra Cricket Association Stadium                 15
# Kingsmead                                               15
# Sardar Patel Stadium, Motera                            12
# SuperSport Park                                         12
# Brabourne Stadium                                       11
# Punjab Cricket Association IS Bindra Stadium, Mohali    11
# ...

# %%
(num_sixes/num_matches).sort_values(ascending=False)
# Out:
# venue
# Holkar Cricket Stadium                                  17.600000
# M Chinnaswamy Stadium                                   13.227273
# Sharjah Cricket Stadium                                 12.666667
# Himachal Pradesh Cricket Association Stadium            12.000000
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11.727273
# Wankhede Stadium                                        11.526316
# De Beers Diamond Oval                                   11.333333
# Maharashtra Cricket Association Stadium                 11.266667
# JSCA International Stadium Complex                      10.857143
# Sardar Patel Stadium, Motera                            10.833333
# Feroz Shah Kotla                                        10.600000
# MA Chidambaram Stadium, Chepauk                         10.562500
# Saurashtra Cricket Association Stadium                  10.400000
# Brabourne Stadium                                       10.363636
# ...

# %%
#find orange cap holder of every season

temp_df
# Out:
#         match_id  inning                 batting_team  \
# 10             1       1          Sunrisers Hyderabad
# 47             1       1          Sunrisers Hyderabad
# 75             1       1          Sunrisers Hyderabad
# 89             1       1          Sunrisers Hyderabad
# 91             1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150395       636       2  Royal Challengers Bangalore
# 150413       636       2  Royal Challengers Bangalore
# 150428       636       2  Royal Challengers Bangalore
# 150440       636       2  Royal Challengers Bangalore
# 150453       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball       batsman     non_striker  \
# 10      Royal Challengers Bangalore     2     4     DA Warner        S Dhawan
# 47      Royal Challengers Bangalore     8     4  MC Henriques        S Dhawan
# 75      Royal Challengers Bangalore    13     2  Yuvraj Singh    MC Henriques
# ...

# %%
orange_cap = temp_df.groupby(['season','batsman'])['batsman_runs'].sum().reset_index().sort_values('batsman_runs', ascending=False)

# %%
orange_cap
# Out:
#      season          batsman  batsman_runs
# 388    2012         CH Gayle           354
# 486    2013         CH Gayle           312
# 286    2011         CH Gayle           264
# 829    2016          V Kohli           228
# 661    2015         CH Gayle           228
# ..      ...              ...           ...
# 24     2008         JDP Oram             6
# 27     2008  Joginder Sharma             6
# 32     2008         L Ronchi             6
# 34     2008        LPC Silva             6
# 887    2017        MM Sharma             6
#
# [926 rows x 3 columns]
